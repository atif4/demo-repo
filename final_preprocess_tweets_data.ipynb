# %%
# EDA pamages 
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\haier\Python\\python for data analysis\\final_preprocess_tweets_data')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55056 entries, 0 to 55055
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 55056 non-null  int64
#  1   cleaning_user_name         54308 non-null  object
#  2   cleaning_user_location     54027 non-null  object
#  3   cleaning_user_description  54685 non-null  object
#  4   cleaning_text              55056 non-null  object
#  5   cleaning_hashtags          55010 non-null  object
#  6   cleaning_source            55056 non-null  object
#  7   years                      55056 non-null  int64
#  8   months                     55056 non-null  int64
#  9   days                       55056 non-null  int64
#  10  hours                      55056 non-null  int64
#  11  minutes                    55056 non-null  int64
#  12  seconds                    55056 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                      0
# cleaning_user_name            748
# cleaning_user_location       1029
# cleaning_user_description     371
# cleaning_text                   0
# cleaning_hashtags              46
# cleaning_source                 0
# years                           0
# months                          0
# days                            0
# hours                           0
# minutes                         0
# seconds                         0
# Polarity                        0
# Subjectivity                    0
# Sentiment                       0
# dtype: int64

# %%
df
# Out:
#        Unnamed: 0               cleaning_user_name cleaning_user_location  \
# 0               2                   timefisticuffs        pewee valley ky
# 1               3                      ethel mertz           stuck middle
# 2               4                           diprjk          jammu kashmir
# 3               5                   franz schubert                    NaN
# 4               6                     hr bartender         gainesville fl
# ...           ...                              ...                    ...
# 55051       99125                         jpiercea      georgia usa gdecd
# 55052       99127  steve ramona opportunity broker               san jose
# 55053       99128                   alison steeves                toronto
# 55054       99129                 rogers tv london         london ontario
# 55055       99135                   edpublicpolicy            athens ohio
#
#                                cleaning_user_description  \
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# cleaning_user_name           0
# cleaning_user_location       0
# cleaning_user_description    0
# cleaning_text                0
# cleaning_hashtags            0
# cleaning_source              0
# years                        0
# months                       0
# days                         0
# hours                        0
# minutes                      0
# seconds                      0
# Polarity                     0
# Subjectivity                 0
# Sentiment                    0
# dtype: int64

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df
# Out:
#                          cleaning_user_name cleaning_user_location  \
# 2                                    diprjk          jammu kashmir
# 10                           marc goovaerts               brussels
# 12                           florian bieber                   graz
# 14     tetra tech international development      working countries
# 16                     mugilan chandrakumar    epass cross borders
# ...                                     ...                    ...
# 55036            nihr crn north west london         london england
# 55037                    captain starkiller     colchester england
# 55046                     cheatobandito fbr              austin tx
# 55052       steve ramona opportunity broker               san jose
# 55055                        edpublicpolicy            athens ohio
#
#                                cleaning_user_description  \
# 2      official twitter handle department information...
# ...

# %%
dfp = df[df['Sentiment']=='Positive']

# %%
dfp
# Out:
#                          cleaning_user_name cleaning_user_location  \
# 2                                    diprjk          jammu kashmir
# 10                           marc goovaerts               brussels
# 12                           florian bieber                   graz
# 14     tetra tech international development      working countries
# 16                     mugilan chandrakumar    epass cross borders
# ...                                     ...                    ...
# 55036            nihr crn north west london         london england
# 55037                    captain starkiller     colchester england
# 55046                     cheatobandito fbr              austin tx
# 55052       steve ramona opportunity broker               san jose
# 55055                        edpublicpolicy            athens ohio
#
#                                cleaning_user_description  \
# 2      official twitter handle department information...
# ...

# %%
dfn = df[df['Sentiment']=='Negative']

# %%
dfn
# Out:
#        Unnamed: 0                     cleaning_user_name  \
# 1               3                            ethel mertz
# 17             31                               vcinemas
# 22             39                                   ashp
# 36             75                    investmentguruindia
# 50             98                                    gaa
# ...           ...                                    ...
# 55043       99109   electronic health record association
# 55045       99111                      globalpandemicnet
# 55049       99121  minneapolis fed community development
# 55050       99124                           kathy harris
# 55054       99129                       rogers tv london
#
#       cleaning_user_location  \
# 1               stuck middle
# 17             chennai india
# 22         bethesda maryland
# 36                     india
# 50                   ireland
# ...                      ...
# 55043             chicago il
# 55045              worldwide
# ...

# %%
dfna = df[df['Sentiment']=='Natural']

# %%
dfna
# Out:
#        Unnamed: 0 cleaning_user_name cleaning_user_location  \
# 0               2     timefisticuffs        pewee valley ky
# 3               5     franz schubert                    NaN
# 4               6       hr bartender         gainesville fl
# 5               9      member christ          location link
# 6              11        creativegms        dhakabangladesh
# ...           ...                ...                    ...
# 55044       99110          healogics   jacksonville florida
# 55047       99116      michael stahl            astoria nyc
# 55048       99117        groovy toon                     uk
# 55051       99125           jpiercea      georgia usa gdecd
# 55053       99128     alison steeves                toronto
#
#                                cleaning_user_description  \
# 0      christian catholic conservative reagan republi...
# 3       novorossiya stayathome polymath composer english
# 4      workplace tips advice served friendly place co...
# ...
