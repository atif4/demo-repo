# %%
# EDA pamages 
import pandas as pd

# %%
# Data Viz pakages
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#hide earrings 
import warnings
warnings.filterwarnings('ignore')

# %%
#load data
df = pd.read_csv("C:\\Users\\haier\\Downloads\\covid19_tweets.csv")

# %%
#preview the data
df
# Out:
#                      user_name               user_location  \
# 0                       ᏉᎥ☻լꂅϮ                  astroworld
# 1                Tom Basile 🇺🇸                New York, NY
# 2              Time4fisticuffs            Pewee Valley, KY
# 3                  ethel mertz        Stuck in the Middle
# 4                     DIPR-J&K           Jammu and Kashmir
# ...                        ...                         ...
# 179103  AJIMATI AbdulRahman O.             Ilorin, Nigeria
# 179104                   Jason                     Ontario
# 179105             BEEHEMOTH ⏳                   🇨🇦 Canada
# 179106           Gary DelPonte               New York City
# 179107                 TUKY II  Aliwal North, South Africa
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 2       #Christian #Catholic #Conservative #Reagan #Re...
# ...

# %%
import nltk 
from nltk.stem import PorterStemmer
ps = PorterStemmer()
dir(ps)
# Out:
# ['MARTIN_EXTENSIONS',
#  'NLTK_EXTENSIONS',
#  'ORIGINAL_ALGORITHM',
#  '__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_abc_impl',
#  '_apply_rule_list',
#  '_contains_vowel',
#  '_ends_cvc',
#  '_ends_double_consonant',
#  '_has_positive_measure',
#  '_is_consonant',
#  '_measure',
#  '_replace_suffix',
#  '_step1a',
#  '_step1b',
#  '_step1c',
#  '_step2',
#  '_step3',
#  '_step4',
#  '_step5a',
#  '_step5b',
#  'mode',
#  'pool',
#  'stem',
#  'unicode_repr',
#  'vowels']

# %% [raw]
# import re
# import string
# pd.set_option('display.max_colwidth',100)
# stop_words = nltk.corpus.stopwords.words('english')
# data = pd.read_csv("C:\\Users\\haier\\Downloads\\covid19_tweets.csv")
# data.columns=['user_name','user_description']

# %%
df
# Out:
#                      user_name               user_location  \
# 0                       ᏉᎥ☻լꂅϮ                  astroworld
# 1                Tom Basile 🇺🇸                New York, NY
# 2              Time4fisticuffs            Pewee Valley, KY
# 3                  ethel mertz        Stuck in the Middle
# 4                     DIPR-J&K           Jammu and Kashmir
# ...                        ...                         ...
# 179103  AJIMATI AbdulRahman O.             Ilorin, Nigeria
# 179104                   Jason                     Ontario
# 179105             BEEHEMOTH ⏳                   🇨🇦 Canada
# 179106           Gary DelPonte               New York City
# 179107                 TUKY II  Aliwal North, South Africa
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 2       #Christian #Catholic #Conservative #Reagan #Re...
# ...

# %%
df.isnull().sum()
# Out:
# user_name               0
# user_location       36771
# user_description    10286
# user_created            0
# user_followers          0
# user_friends            0
# user_favourites         0
# user_verified           0
# date                    0
# text                    0
# hashtags            51334
# source                 77
# is_retweet              0
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#                      user_name         user_location  \
# 2              Time4fisticuffs      Pewee Valley, KY
# 3                  ethel mertz  Stuck in the Middle
# 4                     DIPR-J&K     Jammu and Kashmir
# 5             🎹 Franz Schubert           Новоро́ссия
# 6                 hr bartender       Gainesville, FL
# ...                        ...                   ...
# 179101       New Jersey Herald            Newton, NJ
# 179102                    Pris                  T.O.
# 179103  AJIMATI AbdulRahman O.       Ilorin, Nigeria
# 179104                   Jason               Ontario
# 179106           Gary DelPonte         New York City
#
#                                          user_description  \
# 2       #Christian #Catholic #Conservative #Reagan #Re...
# 3       #Browns #Indians #ClevelandProud #[]_[] #Cavs ...
# 4       🖊️Official Twitter handle of Department of Inf...
# 5       🎼  #Новоро́ссия #Novorossiya #оставайсядома #S...
# ...

# %%
df.isnull().sum()
# Out:
# user_name           0
# user_location       0
# user_description    0
# user_created        0
# user_followers      0
# user_friends        0
# user_favourites     0
# user_verified       0
# date                0
# text                0
# hashtags            0
# source              0
# is_retweet          0
# dtype: int64

# %%
df=df.apply(lambda x: x.astype(str).str.lower()) # the whole dataset is converted into lowercase()

# %%
#load text cleaning package
import neattext as nfx

# %%
dir(nfx)
# Out:
# ['AUTOMATED_READ_INDEX',
#  'BTC_ADDRESS_REGEX',
#  'CONTRACTIONS_DICT',
#  'CURRENCY_REGEX',
#  'CURRENCY_SYMB_REGEX',
#  'Callable',
#  'Counter',
#  'CreditCard_REGEX',
#  'DATE_REGEX',
#  'EMAIL_REGEX',
#  'EMOJI_REGEX',
#  'FUNCTORS_WORDLIST',
#  'HASTAG_REGEX',
#  'HTML_TAGS_REGEX',
#  'List',
#  'MASTERCard_REGEX',
#  'MD5_SHA_REGEX',
#  'MOST_COMMON_PUNCT_REGEX',
#  'NUMBERS_REGEX',
#  'PHONE_REGEX',
#  'PUNCT_REGEX',
#  'PoBOX_REGEX',
#  'SPECIAL_CHARACTERS_REGEX',
#  'STOPWORDS',
#  'STOPWORDS_de',
#  'STOPWORDS_en',
#  'STOPWORDS_es',
#  'STOPWORDS_fr',
#  'STOPWORDS_ru',
#  'STOPWORDS_yo',
#  'STREET_ADDRESS_REGEX',
#  'TextCleaner',
#  'TextExtractor',
#  'TextFrame',
#  'TextMetrics',
#  'TextPipeline',
#  'Tuple',
#  'URL_PATTERN',
#  'USER_HANDLES_REGEX',
#  'VISACard_REGEX',
#  'ZIP_REGEX',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
# ...

# %%
def get_clean_data_column (new_column_name , column_name ):
    df[new_column_name] = df[column_name].apply(nfx.remove_emojis)
    df[new_column_name] = df[new_column_name].apply(nfx.remove_numbers)
    df[new_column_name] = df[new_column_name].apply(nfx.remove_punctuations)
    df[new_column_name] = df[new_column_name].apply(nfx.remove_special_characters)
    df[new_column_name] = df[new_column_name].apply(nfx.remove_multiple_spaces)
    df[new_column_name] = df[new_column_name].apply(nfx.remove_stopwords)
    return df[new_column_name]
result = get_clean_data_column(new_column_name='cleaning_user_name',column_name='user_name')

# %%
result
# Out:
# 2              timefisticuffs
# 3                 ethel mertz
# 4                      diprjk
# 5              franz schubert
# 6                hr bartender
#                  ...
# 179101      new jersey herald
# 179102                   pris
# 179103    ajimati abdulrahman
# 179104                  jason
# 179106          gary delponte
# Name: cleaning_user_name, Length: 99138, dtype: object

# %%
df[['user_name','cleaning_user_name']].head(50)
# Out:
#                                         user_name  \
# 2                                 time4fisticuffs
# 3                                     ethel mertz
# 4                                        dipr-j&k
# 5                                🎹 franz schubert
# 6                                    hr bartender
# 9               member of christ 🇨🇳🇺🇸🇮🇳🇮🇩🇧🇷🇳🇬🇧🇩🇷🇺
# 11                                    creativegms
# 12                                     sexxylypps
# 13             africa youth advisory board on drr
# 15                                  dimapur 24/7.
# 17                           marc goovaerts🇪🇺🏳️‍🌈
# 23                                          cawst
# 24                                 florian bieber
# 25                             blood donors india
# 26           tetra tech international development
# 27                     beatnikgeek the soothsayer
# 28                           mugilan chandrakumar
# 31                                      v2cinemas
# ...

# %%
#to remove the hashtags from the column of datasetdf['cleaning_user_name']=df['user_name'].apply(nfx.remove_emojis)

# %%
df['cleaning_user_name']=df['cleaning_user_name'].apply(nfx.remove_numbers)

# %%
df['cleaning_user_name']=df['cleaning_user_name'].apply(nfx.remove_punctuations)

# %%
df['cleaning_user_name']=df['cleaning_user_name'].apply(nfx.remove_special_characters)

# %%
df['cleaning_user_name']=df['cleaning_user_name'].apply(nfx.remove_multiple_spaces)

# %%
df['cleaning_user_name']=df['cleaning_user_name'].apply(nfx.remove_stopwords)

# %%
df['cleaning_user_name']=df['cleaning_user_name'].apply(nfx.remove_urls)

# %%
df['cleaning_user_name']=df['cleaning_user_name'].apply(nfx.remove_visacard_addr)

# %%
df['cleaning_user_name']=df['cleaning_user_name'].apply(nfx.remove_terms_in_bracket)

# %%
df['cleaning_user_name']=df['cleaning_user_name'].apply(nfx.remove_street_address)

# %%
df['cleaning_user_name']=df['cleaning_user_name'].apply(nfx.remove_puncts)

# %%
df['cleaning_user_name']=df['cleaning_user_name'].apply(nfx.remove_postoffice_box)

# %%
df['cleaning_user_name']=df['cleaning_user_name'].apply(nfx.remove_phone_numbers)

# %%
df['cleaning_user_name']=df['cleaning_user_name'].apply(nfx.remove_html_tags)

# %%
df['cleaning_user_name']=df['cleaning_user_name'].apply(nfx.remove_currency_symbols)

# %%
df[['user_name','cleaning_user_name']].head(20)
# Out:
#                                user_name                    cleaning_user_name
# 2                        time4fisticuffs                        timefisticuffs
# 3                            ethel mertz                           ethel mertz
# 4                               dipr-j&k                                diprjk
# 5                       🎹 franz schubert                        franz schubert
# 6                           hr bartender                          hr bartender
# 9      member of christ 🇨🇳🇺🇸🇮🇳🇮🇩🇧🇷🇳🇬🇧🇩🇷🇺                         member christ
# 11                           creativegms                           creativegms
# 12                            sexxylypps                            sexxylypps
# 13    africa youth advisory board on drr       africa youth advisory board drr
# 15                         dimapur 24/7.                               dimapur
# 17                  marc goovaerts🇪🇺🏳️‍🌈                        marc goovaerts
# ...

# %%
def get_clean_list (new_column_name):
    clean_list = df[new_column_name].apply(nfx.remove_stopwords).tolist()
    return clean_list
result = get_clean_list('cleaning_user_name')

# %%
result
# Out:
# ['timefisticuffs',
#  'ethel mertz',
#  'diprjk',
#  'franz schubert',
#  'hr bartender',
#  'member christ',
#  'creativegms',
#  'sexxylypps',
#  'africa youth advisory board drr',
#  'dimapur',
#  'marc goovaerts',
#  'cawst',
#  'florian bieber',
#  'blood donors india',
#  'tetra tech international development',
#  'beatnikgeek soothsayer',
#  'mugilan chandrakumar',
#  'vcinemas',
#  'beautify data',
#  'alan taylor',
#  'harleyb',
#  'mr gazz',
#  'ashp',
#  'aishling sheridan',
#  'matthew mcgee',
#  'n c ta h',
#  'toi delhi',
#  'dr k surender raj',
#  'barry grodenchik',
#  'carlino',
#  '',
#  'jazmine',
#  'charles mapundu',
#  'stephen williams',
#  'bestvaluebuttons',
#  'whitey',
#  'investmentguruindia',
#  'st jude india childcare centres',
#  'imf',
#  'john dalton',
#  'dr john stanton climateemergency scotlandxr',
#  'cholderton farm shop',
#  'sales business coach rakesh sharma',
#  'new straits times',
#  'national herald',
#  'max',
#  'senator g craughwell',
# ...

# %%
cleaning_user_name_list =df['cleaning_user_name'].apply(nfx.remove_stopwords).tolist()

# %%
cleaning_user_name_list
# Out:
# ['timefisticuffs',
#  'ethel mertz',
#  'diprjk',
#  'franz schubert',
#  'hr bartender',
#  'member christ',
#  'creativegms',
#  'sexxylypps',
#  'africa youth advisory board drr',
#  'dimapur',
#  'marc goovaerts',
#  'cawst',
#  'florian bieber',
#  'blood donors india',
#  'tetra tech international development',
#  'beatnikgeek soothsayer',
#  'mugilan chandrakumar',
#  'vcinemas',
#  'beautify data',
#  'alan taylor',
#  'harleyb',
#  'mr gazz',
#  'ashp',
#  'aishling sheridan',
#  'matthew mcgee',
#  'n c ta h',
#  'toi delhi',
#  'dr k surender raj',
#  'barry grodenchik',
#  'carlino',
#  '',
#  'jazmine',
#  'charles mapundu',
#  'stephen williams',
#  'bestvaluebuttons',
#  'whitey',
#  'investmentguruindia',
#  'st jude india childcare centres',
#  'imf',
#  'john dalton',
#  'dr john stanton climateemergency scotlandxr',
#  'cholderton farm shop',
#  'sales business coach rakesh sharma',
#  'new straits times',
#  'national herald',
#  'max',
#  'senator g craughwell',
# ...

# %%
def get_token (function_name):
    tokens = [token for line in function_name for token in line.split()]
    return tokens 
result = get_token(get_clean_list('cleaning_user_name'))

# %%
result
# Out:
# ['timefisticuffs',
#  'ethel',
#  'mertz',
#  'diprjk',
#  'franz',
#  'schubert',
#  'hr',
#  'bartender',
#  'member',
#  'christ',
#  'creativegms',
#  'sexxylypps',
#  'africa',
#  'youth',
#  'advisory',
#  'board',
#  'drr',
#  'dimapur',
#  'marc',
#  'goovaerts',
#  'cawst',
#  'florian',
#  'bieber',
#  'blood',
#  'donors',
#  'india',
#  'tetra',
#  'tech',
#  'international',
#  'development',
#  'beatnikgeek',
#  'soothsayer',
#  'mugilan',
#  'chandrakumar',
#  'vcinemas',
#  'beautify',
#  'data',
#  'alan',
#  'taylor',
#  'harleyb',
#  'mr',
#  'gazz',
#  'ashp',
#  'aishling',
#  'sheridan',
#  'matthew',
#  'mcgee',
#  'n',
#  'c',
#  'ta',
#  'h',
#  'toi',
#  'delhi',
#  'dr',
#  'k',
#  'surender',
#  'raj',
#  'barry',
#  'grodenchik',
#  'carlino',
#  'jazmine',
#  'charles',
#  'mapundu',
#  'stephen',
#  'williams',
#  'bestvaluebuttons',
#  'whitey',
#  'investmentguruindia',
#  'st',
#  'jude',
#  'india',
#  'childcare',
#  'centres',
#  'imf',
# ...

# %%
cleaning_user_name_token = [token for line in cleaning_user_name_list for token in line.split()]

# %%
cleaning_user_name_token
# Out:
# ['timefisticuffs',
#  'ethel',
#  'mertz',
#  'diprjk',
#  'franz',
#  'schubert',
#  'hr',
#  'bartender',
#  'member',
#  'christ',
#  'creativegms',
#  'sexxylypps',
#  'africa',
#  'youth',
#  'advisory',
#  'board',
#  'drr',
#  'dimapur',
#  'marc',
#  'goovaerts',
#  'cawst',
#  'florian',
#  'bieber',
#  'blood',
#  'donors',
#  'india',
#  'tetra',
#  'tech',
#  'international',
#  'development',
#  'beatnikgeek',
#  'soothsayer',
#  'mugilan',
#  'chandrakumar',
#  'vcinemas',
#  'beautify',
#  'data',
#  'alan',
#  'taylor',
#  'harleyb',
#  'mr',
#  'gazz',
#  'ashp',
#  'aishling',
#  'sheridan',
#  'matthew',
#  'mcgee',
#  'n',
#  'c',
#  'ta',
#  'h',
#  'toi',
#  'delhi',
#  'dr',
#  'k',
#  'surender',
#  'raj',
#  'barry',
#  'grodenchik',
#  'carlino',
#  'jazmine',
#  'charles',
#  'mapundu',
#  'stephen',
#  'williams',
#  'bestvaluebuttons',
#  'whitey',
#  'investmentguruindia',
#  'st',
#  'jude',
#  'india',
#  'childcare',
#  'centres',
#  'imf',
# ...

# %%
from collections import Counter

# %%
def get_tokens(docx,nums=30):
    word_tokens = Counter(docx)
    most_common = word_tokens.most_common(nums)
    result = dict(most_common)
    return result

# %%
get_tokens(cleaning_user_name_token)
# Out:
# {'news': 3403,
#  'dr': 1385,
#  'india': 1209,
#  'health': 1170,
#  'times': 836,
#  'covid': 711,
#  'md': 678,
#  'english': 491,
#  'john': 487,
#  'david': 482,
#  'global': 479,
#  'business': 465,
#  'michael': 428,
#  'world': 404,
#  'covidnewsch': 402,
#  'new': 401,
#  'phd': 392,
#  'j': 377,
#  'today': 349,
#  'kumar': 344,
#  'james': 341,
#  'national': 333,
#  'mark': 331,
#  'daily': 330,
#  'blood': 326,
#  'radio': 325,
#  'globalpandemicnet': 320,
#  'abscbn': 294,
#  'pib': 293,
#  'peter': 288}

# %%
def get_most_common (token):
    most_common = get_tokens(token)
    user_info_df = pd.DataFrame(most_common.items(),columns=['words','score'])
    return user_info_df

# %%
result = get_most_common(cleaning_user_name_token)
result
# Out:
#                 words  score
# 0                news   3403
# 1                  dr   1385
# 2               india   1209
# 3              health   1170
# 4               times    836
# 5               covid    711
# 6                  md    678
# 7             english    491
# 8                john    487
# 9               david    482
# 10             global    479
# 11           business    465
# 12            michael    428
# 13              world    404
# 14        covidnewsch    402
# 15                new    401
# 16                phd    392
# 17                  j    377
# 18              today    349
# 19              kumar    344
# 20              james    341
# 21           national    333
# 22               mark    331
# 23              daily    330
# 24              blood    326
# 25              radio    325
# 26  globalpandemicnet    320
# 27             abscbn    294
# 28                pib    293
# 29              peter    288

# %%
most_common_user_names = get_tokens(cleaning_user_name_token)
user_names_df = pd.DataFrame(most_common_user_names.items(),columns=['words','score'])
user_names_df
# Out:
#                 words  score
# 0                news   3403
# 1                  dr   1385
# 2               india   1209
# 3              health   1170
# 4               times    836
# 5               covid    711
# 6                  md    678
# 7             english    491
# 8                john    487
# 9               david    482
# 10             global    479
# 11           business    465
# 12            michael    428
# 13              world    404
# 14        covidnewsch    402
# 15                new    401
# 16                phd    392
# 17                  j    377
# 18              today    349
# 19              kumar    344
# 20              james    341
# 21           national    333
# 22               mark    331
# 23              daily    330
# 24              blood    326
# 25              radio    325
# 26  globalpandemicnet    320
# 27             abscbn    294
# 28                pib    293
# 29              peter    288

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99138 entries, 2 to 179106
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_name           99138 non-null  object
#  1   user_location       99138 non-null  object
#  2   user_description    99138 non-null  object
#  3   user_created        99138 non-null  object
#  4   user_followers      99138 non-null  object
#  5   user_friends        99138 non-null  object
#  6   user_favourites     99138 non-null  object
#  7   user_verified       99138 non-null  object
#  8   date                99138 non-null  object
#  9   text                99138 non-null  object
#  10  hashtags            99138 non-null  object
#  11  source              99138 non-null  object
#  12  is_retweet          99138 non-null  object
#  13  cleaning_user_name  99138 non-null  object
# dtypes: object(14)
# memory usage: 11.3+ MB

# %%
df.columns
# Out:
# Index(['user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'is_retweet',
#        'cleaning_user_name'],
#       dtype='object')

# %%
df['user_created']#it is in object type to convert into datetime
# Out:
# 2         2009-02-28 18:57:41
# 3         2019-03-07 01:45:06
# 4         2017-02-12 06:45:15
# 5         2018-03-19 16:29:52
# 6         2008-08-12 18:19:49
#                  ...
# 179101    2010-01-07 18:19:37
# 179102    2008-12-31 16:16:12
# 179103    2013-12-30 18:59:19
# 179104    2011-12-21 04:41:30
# 179106    2009-10-27 17:43:13
# Name: user_created, Length: 99138, dtype: object

# %%
def get_time_date(column_name,new_column_name_year,new_column_name_month,new_column_name_day):
    df[column_name] = pd.to_datetime(df[column_name])#it is in object type to convert into datetime 
    df[new_column_name_year]=df[column_name].dt.year
    df[new_column_name_month]=df[column_name].dt.month
    df[new_column_name_day]=df[column_name].dt.day

# %%
get_time_date(column_name = 'user_created', new_column_name_year = 'years', new_column_name_month = 'months', new_column_name_day = 'days')

# %%
df[['user_created','years','months','days']]
# Out:
#               user_created  years  months  days
# 2      2009-02-28 18:57:41   2009       2    28
# 3      2019-03-07 01:45:06   2019       3     7
# 4      2017-02-12 06:45:15   2017       2    12
# 5      2018-03-19 16:29:52   2018       3    19
# 6      2008-08-12 18:19:49   2008       8    12
# ...                    ...    ...     ...   ...
# 179101 2010-01-07 18:19:37   2010       1     7
# 179102 2008-12-31 16:16:12   2008      12    31
# 179103 2013-12-30 18:59:19   2013      12    30
# 179104 2011-12-21 04:41:30   2011      12    21
# 179106 2009-10-27 17:43:13   2009      10    27
#
# [99138 rows x 4 columns]

# %%
df[['user_verified']]
# Out:
#        user_verified
# 2              false
# 3              false
# 4              false
# 5              false
# 6              false
# ...              ...
# 179101         false
# 179102         false
# 179103         false
# 179104         false
# 179106         false
#
# [99138 rows x 1 columns]

# %%
a = pd.get_dummies(df['user_verified'])

# %%
a
# Out:
#         false  true
# 2           1     0
# 3           1     0
# 4           1     0
# 5           1     0
# 6           1     0
# ...       ...   ...
# 179101      1     0
# 179102      1     0
# 179103      1     0
# 179104      1     0
# 179106      1     0
#
# [99138 rows x 2 columns]

# %%
df
# Out:
#                      user_name         user_location  \
# 2              time4fisticuffs      pewee valley, ky
# 3                  ethel mertz  stuck in the middle
# 4                     dipr-j&k     jammu and kashmir
# 5             🎹 franz schubert           новоро́ссия
# 6                 hr bartender       gainesville, fl
# ...                        ...                   ...
# 179101       new jersey herald            newton, nj
# 179102                    pris                  t.o.
# 179103  ajimati abdulrahman o.       ilorin, nigeria
# 179104                   jason               ontario
# 179106           gary delponte         new york city
#
#                                          user_description        user_created  \
# 2       #christian #catholic #conservative #reagan #re... 2009-02-28 18:57:41
# 3       #browns #indians #clevelandproud #[]_[] #cavs ... 2019-03-07 01:45:06
# 4       🖊️official twitter handle of department of inf... 2017-02-12 06:45:15
# ...

# %%
df['user_created'] = pd.to_datetime(df['user_created'])#it is in object type to convert into datetime 
df['user_created'] # now it's type is datatime
# Out:
# 2        2009-02-28 18:57:41
# 3        2019-03-07 01:45:06
# 4        2017-02-12 06:45:15
# 5        2018-03-19 16:29:52
# 6        2008-08-12 18:19:49
#                  ...
# 179101   2010-01-07 18:19:37
# 179102   2008-12-31 16:16:12
# 179103   2013-12-30 18:59:19
# 179104   2011-12-21 04:41:30
# 179106   2009-10-27 17:43:13
# Name: user_created, Length: 99138, dtype: datetime64[ns]

# %%
#years
df['user_created'].dt.year
# Out:
# 2         2009
# 3         2019
# 4         2017
# 5         2018
# 6         2008
#           ...
# 179101    2010
# 179102    2008
# 179103    2013
# 179104    2011
# 179106    2009
# Name: user_created, Length: 99138, dtype: int64

# %%
#months
df['user_created'].dt.month
# Out:
# 2          2
# 3          3
# 4          2
# 5          3
# 6          8
#           ..
# 179101     1
# 179102    12
# 179103    12
# 179104    12
# 179106    10
# Name: user_created, Length: 99138, dtype: int64

# %%
#days
df['user_created'].dt.day
# Out:
# 2         28
# 3          7
# 4         12
# 5         19
# 6         12
#           ..
# 179101     7
# 179102    31
# 179103    30
# 179104    21
# 179106    27
# Name: user_created, Length: 99138, dtype: int64

# %%
df['years']=df['user_created'].dt.year 
df['months']=df['user_created'].dt.month
df['days']=df['user_created'].dt.day

# %%
df[['user_created','years','months','days']]
# Out:
#               user_created  years  months  days
# 2      2009-02-28 18:57:41   2009       2    28
# 3      2019-03-07 01:45:06   2019       3     7
# 4      2017-02-12 06:45:15   2017       2    12
# 5      2018-03-19 16:29:52   2018       3    19
# 6      2008-08-12 18:19:49   2008       8    12
# ...                    ...    ...     ...   ...
# 179101 2010-01-07 18:19:37   2010       1     7
# 179102 2008-12-31 16:16:12   2008      12    31
# 179103 2013-12-30 18:59:19   2013      12    30
# 179104 2011-12-21 04:41:30   2011      12    21
# 179106 2009-10-27 17:43:13   2009      10    27
#
# [99138 rows x 4 columns]

# %%
plt.figure(figsize=(20,10))
sns.barplot( x = 'words', y = 'score', data=user_names_df)
plt.xticks(rotation =45)
plt.title("Most_Common_User_Names")
plt.show()

# %%
user_names_df
# Out:
#                 words  score
# 0                news   3403
# 1                  dr   1385
# 2               india   1209
# 3              health   1170
# 4               times    836
# 5               covid    711
# 6                  md    678
# 7             english    491
# 8                john    487
# 9               david    482
# 10             global    479
# 11           business    465
# 12            michael    428
# 13              world    404
# 14        covidnewsch    402
# 15                new    401
# 16                phd    392
# 17                  j    377
# 18              today    349
# 19              kumar    344
# 20              james    341
# 21           national    333
# 22               mark    331
# 23              daily    330
# 24              blood    326
# 25              radio    325
# 26  globalpandemicnet    320
# 27             abscbn    294
# 28                pib    293
# 29              peter    288

# %%
#pip install wordcloud
from wordcloud import WordCloud

# %%
def plot_wordcloud(docx):
    my_wordcloud = WordCloud().generate(docx)
    plt.imshow(my_wordcloud,interpolation='bilinear')
    plt.axis('off')
    plt.show()
    user_name_docx = ' '.join(cleaning_user_name_token)

# %%
user_name_docx = ' '.join(cleaning_user_name_token)

# %%
plot_wordcloud(user_name_docx)

# %%
df
# Out:
#                      user_name         user_location  \
# 2              time4fisticuffs      pewee valley, ky
# 3                  ethel mertz  stuck in the middle
# 4                     dipr-j&k     jammu and kashmir
# 5             🎹 franz schubert           новоро́ссия
# 6                 hr bartender       gainesville, fl
# ...                        ...                   ...
# 179101       new jersey herald            newton, nj
# 179102                    pris                  t.o.
# 179103  ajimati abdulrahman o.       ilorin, nigeria
# 179104                   jason               ontario
# 179106           gary delponte         new york city
#
#                                          user_description        user_created  \
# 2       #christian #catholic #conservative #reagan #re... 2009-02-28 18:57:41
# 3       #browns #indians #clevelandproud #[]_[] #cavs ... 2019-03-07 01:45:06
# 4       🖊️official twitter handle of department of inf... 2017-02-12 06:45:15
# ...

# %%
#df.drop(['cleanomg_user_name'],axis=1,inplace=True)

# %%
df['cleaning_user_location'] = df['user_location'].apply(nfx.remove_emojis)

# %%
df['cleaning_user_location'] = df['cleaning_user_location'].apply(nfx.remove_punctuations)

# %%
df['cleaning_user_location'] = df['cleaning_user_location'].apply(nfx.remove_special_characters)

# %%
df['cleaning_user_location'] = df['cleaning_user_location'].apply(nfx.remove_numbers)

# %%
df['cleaning_user_location'] = df['cleaning_user_location'].apply(nfx.remove_stopwords)

# %%
df[['user_location','cleaning_user_location']].head(50)
# Out:
#                                         user_location  \
# 2                                    pewee valley, ky
# 3                                stuck in the middle
# 4                                   jammu and kashmir
# 5                                         новоро́ссия
# 6                                     gainesville, fl
# 9                          👇🏻location at link below👇🏻
# 11                                   dhaka,bangladesh
# 12  hotel living - various cities!  who needs a ho...
# 13                                             africa
# 15                                    nagaland, india
# 17                                           brussels
# 23                                     100+ countries
# 24                                               graz
# 25                                      mumbai, india
# 26                          working in 175+ countries
# 27                                      manhattan, ny
# ...

# %%
cleaning_user_location_list= df['cleaning_user_location'].apply(nfx.remove_stopwords).tolist()

# %%
cleaning_user_location_list
# Out:
# ['pewee valley ky',
#  'stuck middle',
#  'jammu kashmir',
#  '',
#  'gainesville fl',
#  'location link',
#  'dhakabangladesh',
#  'hotel living cities needs home hotel living fabulous',
#  'africa',
#  'nagaland india',
#  'brussels',
#  'countries',
#  'graz',
#  'mumbai india',
#  'working countries',
#  'manhattan ny',
#  'epass cross borders',
#  'chennai india',
#  'miami fl',
#  'british columbia canada',
#  'deep heart texas',
#  'dorset uk',
#  'bethesda maryland',
#  'cavan ireland',
#  'uk longer recognise',
#  'port elizabeth south africa',
#  'new delhi india',
#  'chennai',
#  'queens ny',
#  'new orleans la',
#  'astroworld',
#  'marietta ga',
#  'england united kingdom',
#  'ballston spa ny',
#  'denver co',
#  'south',
#  'india',
#  'india',
#  'washington dc',
#  'country run arseclowns',
#  'edinburgh scotland',
#  'cholderton wiltshire sp dr',
#  'new delhi india',
#  'malaysia',
#  'new delhi india',
#  'londonuk',
#  'dublin ireland',
# ...

# %%
cleaning_user_location_token = [token for line in cleaning_user_location_list for token in line.split()]

# %%
cleaning_user_location_token
# Out:
# ['pewee',
#  'valley',
#  'ky',
#  'stuck',
#  'middle',
#  'jammu',
#  'kashmir',
#  'gainesville',
#  'fl',
#  'location',
#  'link',
#  'dhakabangladesh',
#  'hotel',
#  'living',
#  'cities',
#  'needs',
#  'home',
#  'hotel',
#  'living',
#  'fabulous',
#  'africa',
#  'nagaland',
#  'india',
#  'brussels',
#  'countries',
#  'graz',
#  'mumbai',
#  'india',
#  'working',
#  'countries',
#  'manhattan',
#  'ny',
#  'epass',
#  'cross',
#  'borders',
#  'chennai',
#  'india',
#  'miami',
#  'fl',
#  'british',
#  'columbia',
#  'canada',
#  'deep',
#  'heart',
#  'texas',
#  'dorset',
#  'uk',
#  'bethesda',
#  'maryland',
#  'cavan',
#  'ireland',
#  'uk',
#  'longer',
#  'recognise',
#  'port',
#  'elizabeth',
#  'south',
#  'africa',
#  'new',
#  'delhi',
#  'india',
#  'chennai',
#  'queens',
#  'ny',
#  'new',
#  'orleans',
#  'la',
#  'astroworld',
#  'marietta',
#  'ga',
#  'england',
#  'united',
#  'kingdom',
#  'ballston',
#  'spa',
#  'ny',
#  'denver',
#  'co',
# ...

# %%
import nltk
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
input_str = cleaning_user_location_list

for i in input_str:
    a = nltk.word_tokenize(i)
    for word in a:
        print(stemmer.stem(word))
'''
input_str = nltk.word_tokenize(input_str)
for word in input_str:
    print(stemmer.stem(word))
    for j in i:
        a = nltk.word_tokenize(j)
    #print(i)'''
# Out:
# pewe
# valley
# ky
# stuck
# middl
# jammu
# kashmir
# gainesvil
# fl
# locat
# link
# dhakabangladesh
# hotel
# live
# citi
# need
# home
# hotel
# live
# fabul
# africa
# nagaland
# india
# brussel
# countri
# graz
# mumbai
# india
# work
# countri
# manhattan
# ny
# epass
# cross
# border
# chennai
# india
# miami
# fl
# british
# columbia
# canada
# deep
# heart
# texa
# dorset
# uk
# bethesda
# maryland
# cavan
# ireland
# uk
# longer
# recognis
# port
# elizabeth
# south
# africa
# new
# delhi
# india
# chennai
# queen
# ny
# new
# orlean
# la
# astroworld
# marietta
# ga
# england
# unit
# kingdom
# ballston
# spa
# ny
# denver
# co
# south
# india
# india
# washington
# dc
# countri
# run
# arseclown
# edinburgh
# scotland
# cholderton
# wiltshir
# sp
# dr
# new
# delhi
# india
# malaysia
# new
# delhi
# india
# londonuk
# dublin
# ireland
# durban
# south
# africa
# kwathema
# south
# africa
# chennai
# india
# ireland
# cardiff
# beij
# cinema
# junction
# near
# austin
# ...

# %%
# this is list in which each column is mentioned 
lemmatization_columns_list = ['clean_user_name_result1','clean_user_loaction_result1','clean_user_description_result1','clean_text_result1','clean_hashtags_result1','clean_source_result1']
# this is the for loop in columns_list
for lemmatization_column_list in lemmatization_columns_list:
    # here i give some conditions for each columns 
    if lemmatization_column_list == 'clean_user_name_result1':
        # here i call function get_clean_list in different variables
        lemmatized_clean_user_name_result1 = get_lemmatization(clean_user_name_result1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-1150493a1b10> in <module>
#       6     if lemmatization_column_list == 'clean_user_name_result1':
#       7         # here i call function get_clean_list in different variables
# ----> 8         lemmatized_clean_user_name_result1 = get_lemmatization(clean_user_name_result1)
#
# NameError: name 'get_lemmatization' is not defined

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
input_str = cleaning_user_location_list
for i in input_str:
    a = nltk.word_tokenize(i)
    for word in a:
        print(lemmatizer.lemmatize(word))

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
def get_lemmatization(input_str_name):
    input_str =input_str_name 
    for i in input_str:
        a = nltk.word_tokenize(i)
        for word in a:
            print(lemmatizer.lemmatize(word))
get_lemmatization(cleaning_user_location_list)

# %%
get_lemmatization(cleaning_user_description_token)

# %%
cleaning_user_description_token

# %%
cleaning_user_location_token

# %%
import nltk

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
input_str = cleaning_user_location_token
input_str = nltk.word_tokenize(input_str)
for word in input_str:
    print(stemmer.stem(word))

# %%
get_tokens(cleaning_user_location_token)

# %%
result = get_most_common(cleaning_user_location_token)
result

# %%
user_loaction_docx = ' '.join(cleaning_user_location_token)

# %%
plot_wordcloud(user_name_docx)

# %%
cleaning_user_location_token = [token for line in cleaning_user_location_token for token in line.split()]

# %%
df.head(50)

# %%
df['cleaning_user_description'] = df['user_description'].apply(nfx.remove_hashtags)

# %%
df['cleaning_user_description'] = df['cleaning_user_description'].apply(nfx.remove_emojis)

# %%
df['cleaning_user_description'] = df['cleaning_user_description'].apply(nfx.remove_userhandles)

# %%
df['cleaning_user_description'] = df['cleaning_user_description'].apply(nfx.remove_punctuations)

# %%
df['cleaning_user_description'] = df['cleaning_user_description'].apply(nfx.remove_multiple_spaces)

# %%
df['cleaning_user_description'] = df['cleaning_user_description'].apply(nfx.remove_userhandles)

# %%
df['cleaning_user_description'] = df['cleaning_user_description'].apply(nfx.remove_special_characters)

# %%
df['cleaning_user_description'] = df['cleaning_user_description'].apply(nfx.remove_numbers)

# %%
df['cleaning_user_description'] = df['cleaning_user_description'].apply(nfx.remove_stopwords)

# %%
df[['user_description','cleaning_user_description']].head(20)

# %%
df[['user_description','cleaning_user_description']].tail(20)

# %%
cleaning_user_description_list = df['cleaning_user_description'].apply(nfx.remove_stopwords).tolist()

# %%
cleaning_user_description_list

# %%
cleaning_user_description_token = [token for line in cleaning_user_description_list for token in line.split()]

# %%
cleaning_user_description_token

# %%
get_tokens(cleaning_user_description_token)

# %%
result = get_most_common(cleaning_user_description_token)
result
