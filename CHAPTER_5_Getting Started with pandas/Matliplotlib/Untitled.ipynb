# %%
import matplotlib as plt
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
df = pd.read_csv("C:\\Users\\haier\\Downloads\\country_wise_latest.csv")

# %%
file = pd.read_csv("C:\\Users\\haier\\Downloads\\archive_(1)\\Admission_Data.csv")
df = pd.DataFrame(file)
df.shape
# Out:
# (23, 18)

# %%
df.sort_values('Rank',inplace=True)

# %%
df['S_no'] = np.arange(1,24,1)

# %%
pd.DataFrame(file,columns=['Name of University', 'Rigor', 'Rank', 'GPA', 'Test Score', 'Essay',
       'Recommendation', 'Interview', 'Extracurricular', 'Talent',
       'Personality', 'First Generation', 'Religious', 'State Residency',
       'Race', 'Volunteer', 'Work Experience', 'Level of Interest','S_no' ])
# Out:
#                               Name of University  Rigor  Rank  GPA  \
# 0                           Princeton University      3     3    3
# 1                               Brown University      3     3    3
# 2   California Institute of Technology (Caltech)      3     2    2
# 3                             Cornell University      3     2    3
# 4                              Dartmouth College      3     3    3
# 5                             Harvard University      1     1    1
# 6    Massachusetts Institute of Technology (MIT)      2     1    2
# 7                            Stanford University      3     3    3
# 8                     University of Pennsylvania      3     2    1
# 9     Washington University in St. Louis (WashU)      3     3    3
# 10                               Yale University      3     3    3
# 11                               Rice University      3     3    3
# 12                               Duke University      3     3    3
# ...

# %%
grope_by = df.groupby('Name of University')
grope_by

# %%
for Name_of_University ,  Name_of_University_df in grope_by:
    print(Name_of_University)
    print(Name_of_University_df)
# Out:
# Brown University
#   Name of University  Rigor  Rank  GPA  Test Score  Essay  Recommendation  \
# 1   Brown University      3     3    3           3      3               3
#
#    Interview  Extracurricular  Talent  Personality  First Generation  \
# 1          1                2       3            3                 1
#
#    Religious  State Residency  Race  Volunteer  Work Experience  \
# 1        0.0                1     1          1                1
#
#    Level of Interest  S_no
# 1                  0    21
# California Institute of Technology (Caltech)
#                              Name of University  Rigor  Rank  GPA  Test Score  \
# 2  California Institute of Technology (Caltech)      3     2    2           3
#
#    Essay  Recommendation  Interview  Extracurricular  Talent  Personality  \
# 2      3               3          0                2       1            3
#
#    First Generation  Religious  State Residency  Race  Volunteer  \
# ...

# %%
grope_by.get_group('Brown University')
# Out:
#   Name of University  Rigor  Rank  GPA  Test Score  Essay  Recommendation  \
# 1   Brown University      3     3    3           3      3               3
#
#    Interview  Extracurricular  Talent  Personality  First Generation  \
# 1          1                2       3            3                 1
#
#    Religious  State Residency  Race  Volunteer  Work Experience  \
# 1        0.0                1     1          1                1
#
#    Level of Interest  S_no
# 1                  0    21

# %%
df.set_index('S_no',inplace=True)

# %%
df.fillna(0,inplace=True) #by inplace argument the zero value becomes perment for overall dataset

# %%
df['S_no'] = np.arange(1,24,1)

# %%
df.loc[:,'Religious']=df.loc[:,'Religious'].apply(pd.to_numeric).astype('int64')

# %% [markdown]
# df.info()

# %%
df.sort_values(by='Rank' , inplace=True)

# %%
#df.sort_index(axis=0)

# %%
#df.sort_index(axis=1)

# %%
S_no = np.arange(1,24,1)

# %% [markdown]
# pd.DataFrame(file,columns=['Name of University', 'Rigor', 'Rank', 'GPA', 'Test Score', 'Essay',
#        'Recommendation', 'Interview', 'Extracurricular', 'Talent',
#        'Personality', 'First Generation', 'Religious', 'State Residency',
#        'Race', 'Volunteer', 'Work Experience', 'Level of Interest','sum_of_experience_and_interest','S_no' ],index=[12,5,22])

# %%
#df.set_index('Rank')

# %%
#df.sort_values(by=['Rank','Name of University'])

# %% [markdown]
# df.index = S_no
# S_no

# %% [markdown]
# df.index

# %% [markdown]
# df.count()

# %% [markdown]
# df.sum() # it gives the total sum of all values of each column

# %% [markdown]
# df.sum(axis=1) # Passing axis=1 sums over the rows instead:

# %% [markdown]
# df.mean(axis=1, skipna=False)

# %% [markdown]
# df[df['Rank']==1]

# %% [markdown]
# df[df['Rank']==2]

# %% [markdown]
# df[df['Rank']==3]

# %% [markdown]
# df.describe()

# %% [markdown]
# df.columns

# %% [raw]
# df.shape

# %% [raw]
# df.index

# %%
'Race' in df
# Out:
# True

# %% [markdown]
# df.isnull()

# %% [markdown]
# df['Name of University']

# %% [markdown]
# df.ix[22]

# %%
df['sum_of_experience_and_interest'] = df['Work Experience'] + df['Level of Interest']

# %%
df['S_no'] = np.arange(1,24,1)

# %% [markdown]
# df

# %% [markdown]
# df.index

# %% [markdown]
# df.style.hidden_index()

# %% [markdown]
# df

# %% [markdown]
# pd.DataFrame(file,columns=['Name of University', 'Rigor', 'Rank', 'GPA', 'Test Score', 'Essay',
#        'Recommendation', 'Interview', 'Extracurricular', 'Talent',
#        'Personality', 'First Generation', 'Religious', 'State Residency',
#        'Race', 'Volunteer', 'Work Experience', 'Level of Interest','sum_of_experience_and_interest'],index=[12,5,22])

# %% [markdown]
# df_1 = pd.DataFrame(file,columns=['Religious', 'Rigor', 'Rank', 'GPA', 'Test Score', 'Essay',
#        'Recommendation', 'Interview', 'Extracurricular', 'Talent',
#        'Personality', 'First Generation', 'Name of University', 'State Residency',
#        'Race', 'Volunteer', 'Work Experience', 'Level of Interest','sum_of_experience_and_interest'],index=[1,13,4])

# %% [markdown]
# df_1

# %% [markdown]
# pd.DataFrame(file,columns=['Religious', 'Rigor', 'Rank', 'GPA', 'Test Score', 'Essay',
#        'Recommendation', 'Interview', 'Extracurricular', 'Talent',
#        'Personality', 'First Generation', 'Name of University', 'State Residency',
#        'Race', 'Volunteer', 'Work Experience', 'Level of Interest'])

# %%
covid = pd.read_csv("C:\\Users\\haier\\Downloads\\country_wise_latest.csv")
part_covid = covid.head(15)
part_covid
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# 5   Antigua and Barbuda         86       3         65      18          4
# 6             Argentina     167416    3059      72575   91782       4890
# 7               Armenia      37390     711      26665   10014         73
# 8             Australia      15303     167       9311    5825        368
# 9               Austria      20558     713      18246    1599         86
# 10           Azerbaijan      30446     423      23242    6781        396
# 11              Bahamas        382      11         91     280         40
# ...

# %%
part_covid.sort_values(by=['Confirmed','Country/Region'])#Country/Region base on confirmed
#rows are sorted on basee of their column names
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 5   Antigua and Barbuda         86       3         65      18          4
# 14             Barbados        110       7         94       9          0
# 11              Bahamas        382      11         91     280         40
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# 1               Albania       4880     144       2745    1991        117
# 8             Australia      15303     167       9311    5825        368
# 9               Austria      20558     713      18246    1599         86
# 2               Algeria      27973    1163      18837    7973        616
# 10           Azerbaijan      30446     423      23242    6781        396
# 0           Afghanistan      36263    1269      25198    9796        106
# 7               Armenia      37390     711      26665   10014         73
# ...

# %%
part_covid.sort_values(by=['Confirmed','Country/Region'],ascending=False)#Country/Region base on confirmed
#rows are sorted on bases of their column names,by default it in ascending order
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 13           Bangladesh     226225    2965     125683   97577       2772
# 6             Argentina     167416    3059      72575   91782       4890
# 12              Bahrain      39482     141      36110    3231        351
# 7               Armenia      37390     711      26665   10014         73
# 0           Afghanistan      36263    1269      25198    9796        106
# 10           Azerbaijan      30446     423      23242    6781        396
# 2               Algeria      27973    1163      18837    7973        616
# 9               Austria      20558     713      18246    1599         86
# 8             Australia      15303     167       9311    5825        368
# 1               Albania       4880     144       2745    1991        117
# 4                Angola        950      41        242     667         18
# 3               Andorra        907      52        803      52         10
# ...

# %%
part_covid.sort_index(axis=1)#axis= 1 represents columns and all colunms nAmes are sorted by default it in ascending order
# Out:
#     1 week % increase  1 week change  Active  Confirmed  Confirmed last week  \
# 0                2.07            737    9796      36263                35526
# 1               17.00            709    1991       4880                 4171
# 2               18.07           4282    7973      27973                23691
# 3                2.60             23      52        907                  884
# 4               26.84            201     667        950                  749
# 5               13.16             10      18         86                   76
# 6               28.02          36642   91782     167416               130774
# 7                6.89           2409   10014      37390                34981
# 8               23.13           2875    5825      15303                12428
# 9                4.13            815    1599      20558                19743
# 10               9.16           2556    6781      30446                27890
# ...

# %%
part_covid.sort_index(axis=1,ascending=False)#axis= 1 represents columns and all colunms nAmes are sorted by default it in ascending order
# Out:
#                WHO Region  Recovered / 100 Cases  Recovered  New recovered  \
# 0   Eastern Mediterranean                  69.49      25198             18
# 1                  Europe                  56.25       2745             63
# 2                  Africa                  67.34      18837            749
# 3                  Europe                  88.53        803              0
# 4                  Africa                  25.47        242              0
# 5                Americas                  75.58         65              5
# 6                Americas                  43.35      72575           2057
# 7                  Europe                  71.32      26665            187
# 8         Western Pacific                  60.84       9311            137
# 9                  Europe                  88.75      18246             37
# 10                 Europe                  76.34      23242            558
# ...

# %%
covid = pd.read_csv("C:\\Users\\haier\\Downloads\\country_wise_latest.csv")
covid
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
for i in covid.iterrows():
    print(i)
# Out:
# (0, Country/Region                      Afghanistan
# Confirmed                                 36263
# Deaths                                     1269
# Recovered                                 25198
# Active                                     9796
# New cases                                   106
# New deaths                                   10
# New recovered                                18
# Deaths / 100 Cases                          3.5
# Recovered / 100 Cases                     69.49
# Deaths / 100 Recovered                     5.04
# Confirmed last week                       35526
# 1 week change                               737
# 1 week % increase                          2.07
# WHO Region                Eastern Mediterranean
# Name: 0, dtype: object)
# (1, Country/Region            Albania
# Confirmed                    4880
# Deaths                        144
# Recovered                    2745
# Active                       1991
# New cases                     117
# ...

# %%
for i,row in covid.iterrows():
    while i <3:
        print(f'i={i}')
        break
# Out:
# i=0
# i=1
# i=2

# %%
for i,row in covid.iterrows():
    while i <3:
        print(f'i={i}')
        print('')
        break
# Out:
# i=0
#
# i=1
#
# i=2

# %%
for i,row in covid.iterrows():
    while i <3:
        print(f'i={i}')
        print('')
        print('Return Row:')
        break
# Out:
# i=0
#
# Return Row:
# i=1
#
# Return Row:
# i=2
#
# Return Row:

# %%
for i,row in covid.iterrows():
    while i <3:
        print(f'i={i}')
        print('')
        print('Return Row:')
        print(row)
        break
# Out:
# i=0
#
# Return Row:
# Country/Region                      Afghanistan
# Confirmed                                 36263
# Deaths                                     1269
# Recovered                                 25198
# Active                                     9796
# New cases                                   106
# New deaths                                   10
# New recovered                                18
# Deaths / 100 Cases                          3.5
# Recovered / 100 Cases                     69.49
# Deaths / 100 Recovered                     5.04
# Confirmed last week                       35526
# 1 week change                               737
# 1 week % increase                          2.07
# WHO Region                Eastern Mediterranean
# Name: 0, dtype: object
# i=1
#
# Return Row:
# Country/Region            Albania
# Confirmed                    4880
# Deaths                        144
# Recovered                    2745
# Active                       1991
# ...

# %%
for i,row in covid.iterrows():
    while i <3:
        print(f'i={i}')
        print('')
        print('Return Row:')
        print(row)
        print('')
        break
# Out:
# i=0
#
# Return Row:
# Country/Region                      Afghanistan
# Confirmed                                 36263
# Deaths                                     1269
# Recovered                                 25198
# Active                                     9796
# New cases                                   106
# New deaths                                   10
# New recovered                                18
# Deaths / 100 Cases                          3.5
# Recovered / 100 Cases                     69.49
# Deaths / 100 Recovered                     5.04
# Confirmed last week                       35526
# 1 week change                               737
# 1 week % increase                          2.07
# WHO Region                Eastern Mediterranean
# Name: 0, dtype: object
#
# i=1
#
# Return Row:
# Country/Region            Albania
# Confirmed                    4880
# Deaths                        144
# Recovered                    2745
# ...

# %%
for i,row in covid.iterrows():
    while i <3:
        print(f'i={i}')
        print('')
        print('Return Row:')
        print(row)
        print('')
        print(f"column Country/Region: { row ['Country/Region']}")
        break
# Out:
# i=0
#
# Return Row:
# Country/Region                      Afghanistan
# Confirmed                                 36263
# Deaths                                     1269
# Recovered                                 25198
# Active                                     9796
# New cases                                   106
# New deaths                                   10
# New recovered                                18
# Deaths / 100 Cases                          3.5
# Recovered / 100 Cases                     69.49
# Deaths / 100 Recovered                     5.04
# Confirmed last week                       35526
# 1 week change                               737
# 1 week % increase                          2.07
# WHO Region                Eastern Mediterranean
# Name: 0, dtype: object
#
# column Country/Region: Afghanistan
# i=1
#
# Return Row:
# Country/Region            Albania
# Confirmed                    4880
# Deaths                        144
# ...

# %%
for i,row in covid.iterrows():
    while i <3:
        print(f'i={i}')
        print('')
        print('Return Row:')
        print(row)
        print('')
        print(f"column Country/Region: { row ['Country/Region']}")
        print("<-------------------------------------------------->")
        print('')
        break
# Out:
# i=0
#
# Return Row:
# Country/Region                      Afghanistan
# Confirmed                                 36263
# Deaths                                     1269
# Recovered                                 25198
# Active                                     9796
# New cases                                   106
# New deaths                                   10
# New recovered                                18
# Deaths / 100 Cases                          3.5
# Recovered / 100 Cases                     69.49
# Deaths / 100 Recovered                     5.04
# Confirmed last week                       35526
# 1 week change                               737
# 1 week % increase                          2.07
# WHO Region                Eastern Mediterranean
# Name: 0, dtype: object
#
# column Country/Region: Afghanistan
# <-------------------------------------------------->
#
# i=1
#
# Return Row:
# Country/Region            Albania
# Confirmed                    4880
# ...
