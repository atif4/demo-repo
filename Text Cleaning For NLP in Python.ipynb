# %%
import pandas as pd
import numpy as np
from pandas import Series , DataFrame
#load text cleaning package
import neattext as nfx

# %%
#hide earrings 
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:\\Users\\haier\\Downloads\\labeled_data.csv\\labeled_data.csv')

# %%
df
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0               0      3            0                   0        3      2
# 1               1      3            0                   3        0      1
# 2               2      3            0                   3        0      1
# 3               3      3            0                   2        1      1
# 4               4      6            0                   6        0      1
# ...           ...    ...          ...                 ...      ...    ...
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet
# 0      !!! RT @mayasolovely: As a woman you shouldn't...
# 1      !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# ...                                                  ...
# 24778  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779  you've gone and broke the wrong heart baby, an...
# 24780  young buck wanna eat!!.. dat nigguh like I ain...
# 24781              youu got wild bitches tellin you lies
# 24782  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
# [24783 rows x 7 columns]

# %%
df=df.apply(lambda x: x.astype(str).str.lower()) # the whole dataset is converted into lowercase()

# %%
df
# Out:
#       Unnamed: 0 count hate_speech offensive_language neither class  \
# 0              0     3           0                  0       3     2
# 1              1     3           0                  3       0     1
# 2              2     3           0                  3       0     1
# 3              3     3           0                  2       1     1
# 4              4     6           0                  6       0     1
# ...          ...   ...         ...                ...     ...   ...
# 24778      25291     3           0                  2       1     1
# 24779      25292     3           0                  1       2     2
# 24780      25294     3           0                  3       0     1
# 24781      25295     6           0                  6       0     1
# 24782      25296     3           0                  0       3     2
#
#                                                    tweet
# 0      !!! rt @mayasolovely: as a woman you shouldn't...
# 1      !!!!! rt @mleew17: boy dats cold...tyga dwn ba...
# 2      !!!!!!! rt @urkindofbrand dawg!!!! rt @80sbaby...
# 3      !!!!!!!!! rt @c_g_anderson: @viva_based she lo...
# 4      !!!!!!!!!!!!! rt @shenikaroberts: the shit you...
# ...                                                  ...
# 24778  you's a muthaf***in lie &#8220;@lifeasking: @2...
# 24779  you've gone and broke the wrong heart baby, an...
# 24780  young buck wanna eat!!.. dat nigguh like i ain...
# 24781              youu got wild bitches tellin you lies
# 24782  ~~ruffled | ntac eileen dahlia - beautiful col...
#
# [24783 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          24783 non-null  object
#  1   count               24783 non-null  object
#  2   hate_speech         24783 non-null  object
#  3   offensive_language  24783 non-null  object
#  4   neither             24783 non-null  object
#  5   class               24783 non-null  object
#  6   tweet               24783 non-null  object
# dtypes: object(7)
# memory usage: 1.3+ MB

# %% [raw]
# s = df.iloc[0:24783]['tweet']

# %% [raw]
# s

# %% [raw]
# #method # 1 oop using textfram
# list = []
# for i in s:
#     i = 0
#     docx = nfx.TextFrame(s[i])
#     list.append(s[i])
#     i += 1
# docx.describe()

# %%
s = df.iloc[3]['tweet']
docx = nfx.TextFrame(s)

# %%
docx.describe()
# Out:
# Key      Value
# Length  : 62
# vowels  : 14
# consonants: 25
# stopwords: 2
# punctuations: 15
# special_char: 15
# tokens(whitespace): 9
# tokens(words): 9

# %% [raw]
# df = df[['tweet','class']]

# %% [raw]
# df

# %%
#load text cleaning package
import neattext as nfx

# %%
# this function used to clean the data 
def get_clean_data_column (new_column_name , column_name ):
    df[new_column_name] = df[column_name].apply(nfx.remove_emojis)
    df[new_column_name] = df[new_column_name].apply(nfx.remove_numbers)
    df[new_column_name] = df[new_column_name].apply(nfx.remove_punctuations)
    df[new_column_name] = df[new_column_name].apply(nfx.remove_special_characters)
    df[new_column_name] = df[new_column_name].apply(nfx.remove_multiple_spaces)
    df[new_column_name] = df[new_column_name].apply(nfx.remove_stopwords)
    df[new_column_name] = df[new_column_name].apply(nfx.remove_urls)
    df[new_column_name] = df[new_column_name].apply(nfx.remove_visacard_addr)
    df[new_column_name] = df[new_column_name].apply(nfx.remove_terms_in_bracket)
    df[new_column_name] = df[new_column_name].apply(nfx.remove_street_address)
    df[new_column_name] = df[new_column_name].apply(nfx.remove_puncts)
    df[new_column_name] = df[new_column_name].apply(nfx.remove_postoffice_box)
    df[new_column_name] = df[new_column_name].apply(nfx.remove_phone_numbers)
    df[new_column_name] = df[new_column_name].apply(nfx.remove_html_tags)
    df[new_column_name] = df[new_column_name].apply(nfx.remove_currency_symbols)
    return df[new_column_name]

# %%
# this is dictionary where i gave the old column and new column names 
dict_names = {'clean_tweets':'tweet'}
#this the loop in dictionary 
for i ,j in dict_names.items():
    #here i m call my custom function to clean the dataset
    result = get_clean_data_column(i,j)

# %%
#all columns are going to clean one after other from top to bottom
df[['tweet','clean_tweets']].head(50)
# Out:
#                                                 tweet  \
# 0   !!! rt @mayasolovely: as a woman you shouldn't...
# 1   !!!!! rt @mleew17: boy dats cold...tyga dwn ba...
# 2   !!!!!!! rt @urkindofbrand dawg!!!! rt @80sbaby...
# 3   !!!!!!!!! rt @c_g_anderson: @viva_based she lo...
# 4   !!!!!!!!!!!!! rt @shenikaroberts: the shit you...
# 5   !!!!!!!!!!!!!!!!!!"@t_madison_x: the shit just...
# 6   !!!!!!"@__brighterdays: i can not just sit up ...
# 7   !!!!&#8220;@selfiequeenbri: cause i'm tired of...
# 8   " &amp; you might not get ya bitch back &amp; ...
# 9   " @rhythmixx_ :hobbies include: fighting maria...
# 10  " keeks is a bitch she curves everyone " lol i...
# 11                 " murda gang bitch its gang land "
# 12  " so hoes that smoke are losers ? " yea ... go...
# 13      " bad bitches is the only thing that i like "
# 14                            " bitch get up off me "
# 15                    " bitch nigga miss me with it "
# 16                             " bitch plz whatever "
# 17                          " bitch who do you love "
# 18                 " bitches get cut off everyday b "
# 19                 " black bottle &amp; a bad bitch "
# 20               " broke bitch cant tell me nothing "
# 21                    " cancel that bitch like nino "
# 22            " cant you see these hoes wont change "
# 23  " fuck no that bitch dont even suck dick " &#1...
# 24  " got ya bitch tip toeing on my hardwood floor...
# 25     " her pussy lips like heaven doors " &#128524;
# 26                       " hoe what its hitting for "
# 27  " i met that pussy on ocean dr . i gave that p...
# 28     " i need a trippy bitch who fuck on hennessy "
# 29  " i spend my money how i want bitch its my bus...
# 30   " i txt my old bitch my new bitch pussy wetter "
# 31  " i'd say im back to the old me but my old bit...
# 32  " if you aint bout that murder game pussy nigg...
# 33     " if you're toes ain't done you pussy stinks "
# 34  " im done with bitter bitches its a wrap for t...
# 35                               " is that ya bitch "
# 36             " it aint nothing to cut a bitch off "
# 37  " jus meet son now he ya mane ass bitches " #s...
# 38  " lames crying over hoes thats tears of a clown "
# 39  " like snoop said in 94 we dont love these hoes "
# 40    " momma said no pussy cats inside my doghouse "
# 41  " most hated but the hoes favorite " #2mw #sev...
# 42  " nice girls bad, make me get naughty. bad yel...
# 43       " pimps up pimps up hoes down " future voice
# 44     " post a picture of that pussy get 200 likes "
# 45  " pussy is a powerful drug " &#128517; #happyh...
# 46        " quick piece of pussy call it a drive by "
# 47  " running round here like some brand new pussy...
# 48  " these bitches even worst they'll send them g...
# 49  " these hoes like niggas that spend money not ...
#
#                                          clean_tweets
# 0   rt mayasolovely woman shouldnt complain cleani...
# 1   rt mleew boy dats coldtyga dwn bad cuffin dat ...
# 2   rt urkindofbrand dawg rt sbabylife fuck bitch ...
# 3            rt cganderson vivabased look like tranny
# 4   rt shenikaroberts shit hear true faker bitch t...
# 5   tmadisonx shit blows meclaim faithful somebody...
# 6          brighterdays sit hate bitch got shit going
# 7   selfiequeenbri cause im tired big bitches comi...
# 8                              amp ya bitch amp thats
# 9      rhythmixx hobbies include fighting mariambitch
# 10  keeks bitch curves lol walked conversation lik...
# 11                         murda gang bitch gang land
# 12                           hoes smoke losers yea ig
# 13                             bad bitches thing like
# 14                                              bitch
# 15                                   bitch nigga miss
# 16                                          bitch plz
# 17                                         bitch love
# 18                             bitches cut everyday b
# 19                         black bottle amp bad bitch
# 20                              broke bitch cant tell
# 21                             cancel bitch like nino
# 22                              cant hoes wont change
# 23  fuck bitch dont suck dick kermit videos bout f...
# 24  got ya bitch tip toeing hardwood floors httptc...
# 25                       pussy lips like heaven doors
# 26                                        hoe hitting
# 27                 met pussy ocean dr gave pussy pill
# 28                    need trippy bitch fuck hennessy
# 29                    spend money want bitch business
# 30               txt old bitch new bitch pussy wetter
# 31                      id im old old bitches excited
# 32             aint bout murder game pussy nigga shut
# 33                       youre toes aint pussy stinks
# 34       im bitter bitches wrap angry bird theres app
# 35                                           ya bitch
# 36                                     aint cut bitch
# 37             jus meet son ya mane ass bitches shots
# 38                lames crying hoes thats tears clown
# 39                     like snoop said dont love hoes
# 40              momma said pussy cats inside doghouse
# 41   hated hoes favorite mw sevenone httptcobmdsvmcrc
# 42  nice girls bad naughty bad yello hoe real nice...
# 43                      pimps pimps hoes future voice
# 44                           post picture pussy likes
# 45   pussy powerful drug happyhumpday httptcorjsymibb
# 46                            quick piece pussy drive
# 47  running round like brand new pussy thats bout ...
# 48                     bitches worst theyll send guys
# 49             hoes like niggas spend money talk bout

# %%
df
# Out:
#       Unnamed: 0 count hate_speech offensive_language neither class  \
# 0              0     3           0                  0       3     2
# 1              1     3           0                  3       0     1
# 2              2     3           0                  3       0     1
# 3              3     3           0                  2       1     1
# 4              4     6           0                  6       0     1
# ...          ...   ...         ...                ...     ...   ...
# 24778      25291     3           0                  2       1     1
# 24779      25292     3           0                  1       2     2
# 24780      25294     3           0                  3       0     1
# 24781      25295     6           0                  6       0     1
# 24782      25296     3           0                  0       3     2
#
#                                                    tweet  \
# 0      !!! rt @mayasolovely: as a woman you shouldn't...
# 1      !!!!! rt @mleew17: boy dats cold...tyga dwn ba...
# 2      !!!!!!! rt @urkindofbrand dawg!!!! rt @80sbaby...
# 3      !!!!!!!!! rt @c_g_anderson: @viva_based she lo...
# 4      !!!!!!!!!!!!! rt @shenikaroberts: the shit you...
# ...                                                  ...
# 24778  you's a muthaf***in lie &#8220;@lifeasking: @2...
# 24779  you've gone and broke the wrong heart baby, an...
# 24780  young buck wanna eat!!.. dat nigguh like i ain...
# 24781              youu got wild bitches tellin you lies
# 24782  ~~ruffled | ntac eileen dahlia - beautiful col...
#
#                                             clean_tweets
# 0      rt mayasolovely woman shouldnt complain cleani...
# 1      rt mleew boy dats coldtyga dwn bad cuffin dat ...
# 2      rt urkindofbrand dawg rt sbabylife fuck bitch ...
# 3               rt cganderson vivabased look like tranny
# 4      rt shenikaroberts shit hear true faker bitch t...
# ...                                                  ...
# 24778  yous muthafin lie lifeasking pearls coreyemanu...
# 24779  youve gone broke wrong heart baby drove rednec...
# 24780  young buck wanna eat dat nigguh like aint fuck...
# 24781                  youu got wild bitches tellin lies
# 24782  ruffled ntac eileen dahlia beautiful color com...
#
# [24783 rows x 8 columns]
