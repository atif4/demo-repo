# %%
# EDA pamages 
import pandas as pd
import numpy as np

# %%
# Data Viz pakages
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#hide earrings 
import warnings
warnings.filterwarnings('ignore')

# %%
#load data
df = pd.read_csv("C:\\Users\\haier\\Downloads\\covid19_tweets.csv")

# %%
#preview the data
df
# Out:
#                      user_name               user_location  \
# 0                       ᏉᎥ☻լꂅϮ                  astroworld
# 1                Tom Basile 🇺🇸                New York, NY
# 2              Time4fisticuffs            Pewee Valley, KY
# 3                  ethel mertz        Stuck in the Middle
# 4                     DIPR-J&K           Jammu and Kashmir
# ...                        ...                         ...
# 179103  AJIMATI AbdulRahman O.             Ilorin, Nigeria
# 179104                   Jason                     Ontario
# 179105             BEEHEMOTH ⏳                   🇨🇦 Canada
# 179106           Gary DelPonte               New York City
# 179107                 TUKY II  Aliwal North, South Africa
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 2       #Christian #Catholic #Conservative #Reagan #Re...
# ...

# %% [raw]
# ####Task
# +Text
#     -Text preprocessing
#     -Sentiment Analysis
#     -Keyword Exraction
#     -Entity Exraction

# %%
#getting overall information of the data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179108 entries, 0 to 179107
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_name         179108 non-null  object
#  1   user_location     142337 non-null  object
#  2   user_description  168822 non-null  object
#  3   user_created      179108 non-null  object
#  4   user_followers    179108 non-null  int64
#  5   user_friends      179108 non-null  int64
#  6   user_favourites   179108 non-null  int64
#  7   user_verified     179108 non-null  bool
#  8   date              179108 non-null  object
#  9   text              179108 non-null  object
#  10  hashtags          127774 non-null  object
#  11  source            179031 non-null  object
#  12  is_retweet        179108 non-null  bool
# dtypes: bool(2), int64(3), object(8)
# memory usage: 15.4+ MB

# %%
#to see how many null values we have overall in dataset
df.isnull().sum()
# Out:
# user_name               0
# user_location       36771
# user_description    10286
# user_created            0
# user_followers          0
# user_friends            0
# user_favourites         0
# user_verified           0
# date                    0
# text                    0
# hashtags            51334
# source                 77
# is_retweet              0
# dtype: int64

# %%
df.dropna()
#(df.dropna(subset=['ID']))
# Out:
#                      user_name         user_location  \
# 2              Time4fisticuffs      Pewee Valley, KY
# 3                  ethel mertz  Stuck in the Middle
# 4                     DIPR-J&K     Jammu and Kashmir
# 5             🎹 Franz Schubert           Новоро́ссия
# 6                 hr bartender       Gainesville, FL
# ...                        ...                   ...
# 179101       New Jersey Herald            Newton, NJ
# 179102                    Pris                  T.O.
# 179103  AJIMATI AbdulRahman O.       Ilorin, Nigeria
# 179104                   Jason               Ontario
# 179106           Gary DelPonte         New York City
#
#                                          user_description  \
# 2       #Christian #Catholic #Conservative #Reagan #Re...
# 3       #Browns #Indians #ClevelandProud #[]_[] #Cavs ...
# 4       🖊️Official Twitter handle of Department of Inf...
# 5       🎼  #Новоро́ссия #Novorossiya #оставайсядома #S...
# ...

# %%
df.isnull().sum()
# Out:
# user_name               0
# user_location       36771
# user_description    10286
# user_created            0
# user_followers          0
# user_friends            0
# user_favourites         0
# user_verified           0
# date                    0
# text                    0
# hashtags            51334
# source                 77
# is_retweet              0
# dtype: int64

# %%
df = df[df['user_location'].isnull()]
#df.isnull().sum()

# %%
def get_unique_value(column_id):
    #"These are unique value"
    unique_info = df[column_id].unique()
    #"This tells how many times a word is repeat or not"
    unique_info_count = df[column_id].value_counts()
    #"Here top 30 values which repeated mostly")
    #plot the top value count 
    unique_info_largest = df[column_id].value_counts().nlargest(30)
    return unique_info , unique_info_count ,unique_info_largest

# %%
columns_id_list=['user_name', 'user_location', 'user_description', 'user_created',
       'user_followers', 'user_friends', 'user_favourites', 'user_verified',
       'date', 'text', 'hashtags', 'source', 'is_retweet']

# %%
index = 0
for column_id_list in columns_id_list:
    print(index,column_id_list)
    index +=1
# Out:
# 0 user_name
# 1 user_location
# 2 user_description
# 3 user_created
# 4 user_followers
# 5 user_friends
# 6 user_favourites
# 7 user_verified
# 8 date
# 9 text
# 10 hashtags
# 11 source
# 12 is_retweet

# %%
for column_id_list in columns_id_list:
    if columns_id_list[0] == index:
        unique_value_user_name = get_unique_value(columns_id_list[0])
    elif column_id_list[1] == index:
        unique_value_user_location = get_unique_value(columns_id_list[1])
        print(unique_value_user_location)

# %%
#unique_value_user_location

# %%
#unique_value_user_name

# %%
for column_id_list in columns_id_list:
    print(column_id_list)
    if column_id_list[0] == column_id_list:
        unique_value_user_name = get_unique_value(column_id_list[0])
    elif column_id_list[1] == column_id_list:
        unique_value_user_location = get_unique_value(column_id_list[1])

# %%
unique_value_user_name

# %%
#unique_value_user_location

# %%
get_unique_value('source')

# %%
#source /value count /disturbuation of source 
df['source'].unique()

# %%
#source /value count /disturbuation of source 
df['source'].value_counts()

# %%
#plot the top value count 
df['source'].value_counts().nlargest(30)

# %%
#plot the top value count 
df['source'].value_counts().nlargest(30).plot(kind='bar')

# %%
#plot the top value count 
plt.figure(figsize=(20,10))
df['source'].value_counts().nlargest(30).plot(kind='bar')
plt.xticks(rotation=45)
plt.show()

# %%
#pip install neattext

# %%
#load text cleaning package
import neattext as nfx

# %%
dir(nfx)

# %%
df['text']

# %%
df['text'].iloc[2]

# %%
df['text'].apply(nfx.extract_hashtags)

# %%
df['extract_hashtags']=df['text'].apply(nfx.extract_hashtags)
df['extract_hashtags']=df['text'].apply(nfx.extract_hashtags)

# %%
df[['extract_hashtags','hashtags']]

# %%
#to remove the hashtags from the column of dataset
df['cleaning_tweets']=df['text'].apply(nfx.remove_hashtags)

# %%
df[['text','cleaning_tweets']]
# Out:
#                                                      text  \
# 0       If I smelled the scent of hand sanitizers toda...
# 1       Hey @Yankees @YankeesPR and @MLB - wouldn't it...
# 2       @diane3443 @wdunlap @realDonaldTrump Trump nev...
# 3       @brookbanktv The one gift #COVID19 has give me...
# 4       25 July : Media Bulletin on Novel #CoronaVirus...
# ...                                                   ...
# 179103  Thanks @IamOhmai for nominating me for the @WH...
# 179104  2020! The year of insanity! Lol! #COVID19 http...
# 179105  @CTVNews A powerful painting by Juan Lucena. I...
# 179106  More than 1,200 students test positive for #CO...
# 179107  I stop when I see a Stop\n\n@SABCNews\n@Izinda...
#
#                                           cleaning_tweets
# 0       If I smelled the scent of hand sanitizers toda...
# 1       Hey @Yankees @YankeesPR and @MLB - wouldn't it...
# 2       @diane3443 @wdunlap @realDonaldTrump Trump nev...
# ...

# %%
df[['text','cleaning_tweets']].iloc[3]

# %%
df['cleaning_tweets'].iloc[10]

# %%
#to remove the space from the column of the dataset
df['cleaning_tweets']=df['cleaning_tweets'].apply(nfx.remove_multiple_spaces)

# %%
df['cleaning_tweets'].iloc[10]

# %%
#to remove the urls from the column of the dataset
df['cleaning_tweets']=df['cleaning_tweets'].apply(nfx.remove_urls)

# %%
df['cleaning_tweets'].iloc[10]

# %%
#to remove the emojis from the column of the dataset
df['cleaning_tweets']=df['cleaning_tweets'].apply(nfx.remove_emojis)

# %%
df['cleaning_tweets'].iloc[12]

# %%
#to remove the userhandles from the column of the dataset
df['cleaning_tweets']=df['cleaning_tweets'].apply(nfx.remove_userhandles)

# %%
df['cleaning_tweets']

# %%
df[['text','cleaning_tweets']].head(20)

# %%
from textblob import TextBlob

# %%
def get_sentiment(text):
    blob = TextBlob(text)
    sentiment_polarity = blob.sentiment.polarity
    sentiment_subjectivity = blob.sentiment.subjectivity
    if sentiment_polarity > 0:
        sentiment_label = 'Positive'
    elif sentiment_polarity < 0 :
        sentiment_label = 'Negative'
    else:
        sentiment_label = 'Natural'
    result = {'Polarity':sentiment_polarity,
            'Subjectivity':sentiment_subjectivity,
            'Sentiment':sentiment_label}
    return result

# %%
#test the function
exl = df['cleaning_tweets'].iloc[0]

# %%
get_sentiment(exl)
# Out:
# {'Polarity': -0.25, 'Subjectivity': 0.25, 'Sentiment': 'Negative'}

# %%
df['sentiment_results'] = df['cleaning_tweets'].apply(get_sentiment)

# %%
df['sentiment_results']
# Out:
# 0         {'Polarity': -0.25, 'Subjectivity': 0.25, 'Sen...
# 1         {'Polarity': 0.5, 'Subjectivity': 0.5, 'Sentim...
# 2         {'Polarity': 0.0, 'Subjectivity': 0.0, 'Sentim...
# 3         {'Polarity': 0.0, 'Subjectivity': 0.3571428571...
# 4         {'Polarity': 0.0, 'Subjectivity': 0.0, 'Sentim...
#                                 ...
# 179103    {'Polarity': 0.2, 'Subjectivity': 0.2, 'Sentim...
# 179104    {'Polarity': 1.0, 'Subjectivity': 0.7, 'Sentim...
# 179105    {'Polarity': 0.3, 'Subjectivity': 1.0, 'Sentim...
# 179106    {'Polarity': 0.26325757575757575, 'Subjectivit...
# 179107    {'Polarity': 0.0, 'Subjectivity': 0.0, 'Sentim...
# Name: sentiment_results, Length: 179108, dtype: object

# %%
df['sentiment_results'].iloc[0]
# Out:
# {'Polarity': -0.25, 'Subjectivity': 0.25, 'Sentiment': 'Negative'}

# %%
from pandas.io.json import json_normalize

# %%
#to see the result of sentiment result in form of table we use this
pd.json_normalize(df['sentiment_results'])
# Out:
#         Polarity  Subjectivity Sentiment
# 0      -0.250000      0.250000  Negative
# 1       0.500000      0.500000  Positive
# 2       0.000000      0.000000   Natural
# 3       0.000000      0.357143   Natural
# 4       0.000000      0.000000   Natural
# ...          ...           ...       ...
# 179103  0.200000      0.200000  Positive
# 179104  1.000000      0.700000  Positive
# 179105  0.300000      1.000000  Positive
# 179106  0.263258      0.515152  Positive
# 179107  0.000000      0.000000   Natural
#
# [179108 rows x 3 columns]

# %%
#to join the columns of sentiment_result to dataset we use this
df = df.join(pd.json_normalize(df['sentiment_results']))

# %%
df.head(5)
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %%
# keyword Exraction", "+ for Positive and Negative Sentiment\n", "+ Gerenal "

# %%
positive_tweet = df[df['Sentiment']=='Positive']['cleaning_tweets']
positive_tweet.head(2)
# Out:
# 1    Hey @Yankees @YankeesPR and @MLB - wouldn't it...
# 6    How   Will Change Work in General (and recruit...
# Name: cleaning_tweets, dtype: object

# %%
natural_tweet = df[df['Sentiment']=='Natural']['cleaning_tweets']
natural_tweet.head(2)
# Out:
# 2    @diane3443 @wdunlap @realDonaldTrump Trump nev...
# 3    @brookbanktv The one gift   has give me is an ...
# Name: cleaning_tweets, dtype: object

# %%
#remove stopworads and convertto tokens
positive_tweet_list = positive_tweet.apply(nfx.remove_stopwords).tolist()
positive_tweet_list
# Out:
# ['Hey @Yankees @YankeesPR @MLB - sense players pay respects A… https://t.co/1QvW0zgyPu',
#  'Change Work General (and recruiting, specifically) via/ @ProactiveTalent https://t.co/bjZxzGPMbK',
#  'Praying good health recovery @ChouhanShivraj .',
#  '👋🏻@PattyHajdu @NavdeepSBains — safe safe. commit ensure… https://t.co/aWCJo6eKvC',
#  "Let's protect real numbers climbing fast Continent. Let's n… https://t.co/byMSfxltrw",
#  'Second wave Flanders..back again... https://t.co/9swImZACMN',
#  'COVID Update: infection rate Florida following natural curve experts predicted initial cu… https://t.co/hmEwE747WK',
#  '@EvanAKilgore @realDonaldTrump Good Patriots! Volunteer Election Judge. Polls open without… https://t.co/qA3mA4zedZ',
#  'comprehensive review &amp; Analysis: key ways WASH help reduce transmission… https://t.co/eCsfDmo9b4',
#  'crosses 2 lakh mark 1,50,055 ppp recovered far. positive today 6988/total… https://t.co/QdJkpcc7qv',
# ...

# %%
df[df['Sentiment'] == 'Positive']
# Out:
#                                  user_name  \
# 1                            Tom Basile 🇺🇸
# 6                             hr bartender
# 8                        Prathamesh Bendre
# 12                              SEXXYLYPPS
# 13      Africa Youth Advisory Board on DRR
# ...                                    ...
# 179096                      laura l. sweet
# 179103              AJIMATI AbdulRahman O.
# 179104                               Jason
# 179105                         BEEHEMOTH ⏳
# 179106                       Gary DelPonte
#
#                                             user_location  \
# 1                                            New York, NY
# 6                                         Gainesville, FL
# 8                                                     NaN
# 12      Hotel living - various cities!  Who needs a ho...
# 13                                                 Africa
# ...                                                   ...
# ...

# %%
df.drop('text',axis=1)
# Out:
#                      user_name               user_location  \
# 0                       ᏉᎥ☻լꂅϮ                  astroworld
# 1                Tom Basile 🇺🇸                New York, NY
# 2              Time4fisticuffs            Pewee Valley, KY
# 3                  ethel mertz        Stuck in the Middle
# 4                     DIPR-J&K           Jammu and Kashmir
# ...                        ...                         ...
# 179103  AJIMATI AbdulRahman O.             Ilorin, Nigeria
# 179104                   Jason                     Ontario
# 179105             BEEHEMOTH ⏳                   🇨🇦 Canada
# 179106           Gary DelPonte               New York City
# 179107                 TUKY II  Aliwal North, South Africa
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 2       #Christian #Catholic #Conservative #Reagan #Re...
# ...

# %%
negative_tweet = df[df['Sentiment']=='Negative']['cleaning_tweets']
negative_tweet.head(2)
# Out:
# 0    If I smelled the scent of hand sanitizers toda...
# 5        deaths continue to rise. It's almost  as b...
# Name: cleaning_tweets, dtype: object

# %%
def get_tweet_list(tweet_list_name):
    tweet_list_name = tweet_list_name.apply(nfx.remove_stopwords).tolist()
    return tweet_list_name

# %%
c=get_tweet_list(negative_tweet)

# %%
a=get_tweet_list(positive_tweet)

# %%
b=get_tweet_list(natural_tweet)

# %%
for line in positive_tweet_list:
    #print(line)
    for token in line.split():
        print(token)

# %%
def get_pnn_token(pnn_list_name):
    pnn_token = [token for line in pnn_list_name for token in line.split()]
    return pnn_token

# %%
get_pnn_token(a)
# Out:
# ['Hey',
#  '@Yankees',
#  '@YankeesPR',
#  '@MLB',
#  '-',
#  'sense',
#  'players',
#  'pay',
#  'respects',
#  'A…',
#  'https://t.co/1QvW0zgyPu',
#  'Change',
#  'Work',
#  'General',
#  '(and',
#  'recruiting,',
#  'specifically)',
#  'via/',
#  '@ProactiveTalent',
#  'https://t.co/bjZxzGPMbK',
#  'Praying',
#  'good',
#  'health',
#  'recovery',
#  '@ChouhanShivraj',
#  '.',
#  '👋🏻@PattyHajdu',
#  '@NavdeepSBains',
#  '—',
#  'safe',
#  'safe.',
#  'commit',
#  'ensure…',
#  'https://t.co/aWCJo6eKvC',
#  "Let's",
#  'protect',
#  'real',
#  'numbers',
#  'climbing',
#  'fast',
#  'Continent.',
#  "Let's",
#  'n…',
#  'https://t.co/byMSfxltrw',
#  'Second',
#  'wave',
#  'Flanders..back',
#  'again...',
#  'https://t.co/9swImZACMN',
#  'COVID',
#  'Update:',
#  'infection',
#  'rate',
#  'Florida',
#  'following',
#  'natural',
#  'curve',
#  'experts',
#  'predicted',
#  'initial',
#  'cu…',
#  'https://t.co/hmEwE747WK',
#  '@EvanAKilgore',
#  '@realDonaldTrump',
#  'Good',
# ...

# %%
#get_pnn_token(negative_tweet)

# %%
#get_pnn_token(natural_tweet)

# %%
pos_token = [token for line in a for token in line.split()]

# %%
pos_token
# Out:
# ['Hey',
#  '@Yankees',
#  '@YankeesPR',
#  '@MLB',
#  '-',
#  'sense',
#  'players',
#  'pay',
#  'respects',
#  'A…',
#  'https://t.co/1QvW0zgyPu',
#  'Change',
#  'Work',
#  'General',
#  '(and',
#  'recruiting,',
#  'specifically)',
#  'via/',
#  '@ProactiveTalent',
#  'https://t.co/bjZxzGPMbK',
#  'Praying',
#  'good',
#  'health',
#  'recovery',
#  '@ChouhanShivraj',
#  '.',
#  '👋🏻@PattyHajdu',
#  '@NavdeepSBains',
#  '—',
#  'safe',
#  'safe.',
#  'commit',
#  'ensure…',
#  'https://t.co/aWCJo6eKvC',
#  "Let's",
#  'protect',
#  'real',
#  'numbers',
#  'climbing',
#  'fast',
#  'Continent.',
#  "Let's",
#  'n…',
#  'https://t.co/byMSfxltrw',
#  'Second',
#  'wave',
#  'Flanders..back',
#  'again...',
#  'https://t.co/9swImZACMN',
#  'COVID',
#  'Update:',
#  'infection',
#  'rate',
#  'Florida',
#  'following',
#  'natural',
#  'curve',
#  'experts',
#  'predicted',
#  'initial',
#  'cu…',
#  'https://t.co/hmEwE747WK',
#  '@EvanAKilgore',
#  '@realDonaldTrump',
#  'Good',
# ...

# %%
neg_token = [token for line in c for token in line.split()]

# %%
nat_token = [token for line in b for token in line.split()]

# %%
nat_token
# Out:
# ['@diane3443',
#  '@wdunlap',
#  '@realDonaldTrump',
#  'Trump',
#  'claimed',
#  'hoax.',
#  'claim',
#  'effort',
#  'to…',
#  'https://t.co/Jkk8vHWHb3',
#  '@brookbanktv',
#  'gift',
#  'appreciation',
#  'simple',
#  'things',
#  'me…',
#  'https://t.co/Z0pOAlFXcW',
#  '25',
#  'July',
#  ':',
#  'Media',
#  'Bulletin',
#  'Novel',
#  '@kansalrohit69',
#  '@DrSyedSehrish',
#  '@airnewsalerts',
#  '@ANI…',
#  'https://t.co/MN0EEcsJHh',
#  'wear',
#  'face',
#  'coverings',
#  'shopping',
#  '-',
#  'includes',
#  'visit',
#  'local',
#  'Community',
#  'Pharmacy…',
#  'https://t.co/OSu5Q4kdd7',
#  'POPE',
#  'GOD',
#  '-',
#  'Prophet',
#  'Sadhu',
#  'Sundar',
#  'Selvaraj.',
#  'Watch',
#  'https://t.co/7X5RTyKVji',
#  'https://t.co/06dZcGUnwL',
#  '49K+',
#  'Covid19',
#  'cases',
#  'response',
#  '@cbseindia29',
#  '@HRDMinistry',
#  '@DrRPNishank.Please',
#  'cancel',
#  'compartment',
#  'exa…',
#  'https://t.co/kV2ZKmumu1',
#  'Order',
#  'here:',
# ...

# %%
from collections import Counter

# %%
def get_tokens(docx,nums=30):
    word_tokens = Counter(docx)
    most_common = word_tokens.most_common(nums)
    result = dict(most_common)
    return result

# %%
get_tokens(pos_token)
# Out:
# {'new': 9858,
#  'cases': 8864,
#  '&amp;': 5302,
#  '-': 4353,
#  'positive': 3676,
#  'people': 3367,
#  'New': 3276,
#  'deaths': 2765,
#  'COVID-19': 2305,
#  'total': 1776,
#  'reported': 1706,
#  'confirmed': 1496,
#  'latest': 1458,
#  '|': 1454,
#  'like': 1414,
#  'need': 1363,
#  'tested': 1349,
#  '24': 1333,
#  'good': 1322,
#  'number': 1258,
#  'safe': 1257,
#  'coronavirus': 1245,
#  'reports': 1244,
#  'Total': 1224,
#  'time': 1203,
#  '.': 1181,
#  'pandemic': 1156,
#  'India': 1142,
#  'health': 1110,
#  'help': 1110}

# %%
most_common_nat_words = get_tokens(nat_token)
nat_df = pd.DataFrame(most_common_nat_words.items(),columns=['words','score'])
nat_df
# Out:
#                words  score
# 0              &amp;   4536
# 1                  -   4263
# 2           COVID-19   2623
# 3              cases   2492
# 4             people   2348
# 5                  |   1898
# 6             deaths   1620
# 7                  :   1557
# 8   @realDonaldTrump   1531
# 9               like   1409
# 10          pandemic   1379
# 11                 .   1348
# 12              need   1320
# 13              help   1258
# 14            August   1140
# 15            health   1074
# 16              2020   1071
# 17              know   1014
# 18       Coronavirus    932
# 19            spread    897
# 20              mask    889
# 21             going    878
# 22       coronavirus    864
# 23            Health    852
# 24             India    850
# 25              time    848
# 26            number    828
# 27              the…    816
# 28              says    804
# 29             Trump    801

# %%
def get_most_common_words(token_name):
    most_common_words = get_tokens(token_name)
    most_common_words_df = pd.DataFrame(most_common_words.items(),columns=['words','score'])
    return most_common_words_df

# %%
get_most_common_words(pos_token)
# Out:
#           words  score
# 0           new   9858
# 1         cases   8864
# 2         &amp;   5302
# 3             -   4353
# 4      positive   3676
# 5        people   3367
# 6           New   3276
# 7        deaths   2765
# 8      COVID-19   2305
# 9         total   1776
# 10     reported   1706
# 11    confirmed   1496
# 12       latest   1458
# 13            |   1454
# 14         like   1414
# 15         need   1363
# 16       tested   1349
# 17           24   1333
# 18         good   1322
# 19       number   1258
# 20         safe   1257
# 21  coronavirus   1245
# 22      reports   1244
# 23        Total   1224
# 24         time   1203
# 25            .   1181
# 26     pandemic   1156
# 27        India   1142
# 28       health   1110
# 29         help   1110

# %%
most_common_pos_words = get_tokens(pos_token)
pos_df = pd.DataFrame(most_common_pos_words.items(),columns=['words','score'])
pos_df

# %%
most_common_neg_words = get_tokens(neg_token)
neg_df = pd.DataFrame(most_common_neg_words.items(),columns=['words','score'])
neg_df

# %%
#plot with sea bone
plt.figure(figsize=(20,10))
sns.barplot(x='words',y='score',data=neg_df)
plt.xticks(rotation=45)
plt.title("Most_Common_Neg_Words")
plt.show()

# %%
#plot with sea bone
plt.figure(figsize=(20,10))
sns.barplot(x='words',y='score',data=pos_df)
plt.xticks(rotation=45)
plt.title("Most_Common_Pos_Words")
plt.show()

# %%
#pip install wordcloud
from wordcloud import WordCloud

# %%
def plot_wordcloud(docx):
    my_wordcloud = WordCloud().generate(docx)
    plt.imshow(my_wordcloud,interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
pos_docx = ' '.join(pos_token)
neg_docx = ' '.join(neg_token)
nat_docx = ' '.join(nat_token)

# %%
plot_wordcloud(pos_docx)

# %%
plot_wordcloud(neg_docx)

# %%
plot_wordcloud(nat_docx)
